# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepss2020/Machine-Learning/blob/main/ML_Lab8_ml_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Implement
# # ***SVM for classification and regression task. Explore the performance of the model with various kernels. Also discuss the role of hyper parameters***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
df = pd.read_csv('Salary.csv')
df.head()
df.shape   
df.drop(columns=['Quarter'], inplace=True)

# %%
X = df.drop(columns=['Year','workers_in_thousands_Total','Median_weekly_earnings_in_constant_dollars_Total',
                     'Median_weekly_earnings_in_current_dollars_Total'],axis=1)
y = df['label']
# print("X and Y Value")
# print(X, y)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=45,stratify=y)

# %%
from sklearn.svm import SVC, SVR
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score

# %%
C = 1.0  # SVM regularization parameter
# LinearSVC (linear kernel)
svc =SVC(kernel='linear', C=C)
svc.fit(X_train, y_train)
y_pred1 = svc.predict(X_test)
print ('Accuracy-svm:', accuracy_score(y_test, y_pred1))
# Out:
# Accuracy-svm: 0.9166666666666666

# %%
confusion_metrics = metrics.confusion_matrix(y_test,y_pred1)
print(confusion_metrics)
# Out:
# [[ 1  1]
#  [ 0 10]]

# %%
# SVC with RBF kernel
rbf_svc =SVC(kernel='rbf', gamma=0.6, C=C)
rbf_svc.fit(X_train, y_train)
y_pred2 = rbf_svc.predict(X_test)
print ('Accuracy-svm:', accuracy_score(y_test, y_pred2))
# Out:
# Accuracy-svm: 0.8333333333333334

# %%
# //WORKING FINE
confusion_metrics2 = metrics.confusion_matrix(y_test,y_pred2)
print(confusion_metrics2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4c8d0f604b6d> in <module>
# ----> 1 confusion_metrics2 = metrics.confusion_matrix(y_test,y_pred2)
#       2 print(confusion_metrics2)
#
# NameError: name 'y_test' is not defined

# %%
# SVC with polynomial (degree 3) kernel
poly_svc =SVC(kernel='poly', degree=5, C=C)
poly_svc.fit(X, y)
y_pred3 = poly_svc.predict(X_test)
print ('Accuracy-svm:', accuracy_score(y_test, y_pred3))
# Out:
# Accuracy-svm: 0.8333333333333334

# %%
confusion_metrics3 = metrics.confusion_matrix(y_test,y_pred3)
print(confusion_metrics3)
# Out:
# [[ 0  2]
#  [ 0 10]]

# %% [markdown]
# ### *Plotting Graph*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import random

# %%
df = pd.read_csv('Salary.csv')
df.shape   
Le = LabelEncoder()

# %%
# X1= df.drop(columns=['Year','Quarter','workers_in_thousands_Total','Median_weekly_earnings_in_constant_dollars_Total',
#                      'Median_weekly_earnings_in_current_dollars_Total'],axis=1)
y1 = df['Median_weekly_earnings_in_constant_dollars_men']
X1 = df['Median_weekly_earnings_in_constant_dollars_Women']
# y1 = df['Median_weekly_earnings_in_constant_dollars_Women']

# %%
import matplotlib.pyplot as plt
# plotting scatters 
N=2
colors = np.random.rand(2)
# 0 to 15 point radii
# print(len(X1),len(y1))
plt.scatter(X1, y1, s=20, c=y1, alpha=0.5)
plt.show()

# plt.scatter(X1[:, 0], X1[:, 1], c=y1, s=50, cmap='spring');
# plt.show() 

xfit = np.linspace(44000, 52000)

# %%
cormat = df.corr()
round(cormat,2)
# Out:
#                                                   Year  Quarter  \
# Year                                              1.00    -0.07
# Quarter                                          -0.07     1.00
# workers_in_thousands_Total                        0.99     0.05
# workers_in thousands_Men                          0.99     0.04
# workers_in_thousands_Women                        0.98     0.06
# Median_weekly_earnings_in_current_dollars_Total   0.97     0.05
# Median_weekly_earnings_in_current_dollars_Men     0.96     0.06
# Median_weekly_earnings_in_current_dollars_Women   0.98     0.04
# Median_weekly_earnings_in_constant_dollars_Total  0.65     0.04
# Median_weekly_earnings_in_constant_dollars_men    0.59     0.06
# Median_weekly_earnings_in_constant_dollars_Women  0.68     0.04
# label                                             0.21    -0.01
#
#                                                   workers_in_thousands_Total  \
# Year                                                                    0.99
# Quarter                                                                 0.05
# workers_in_thousands_Total                                              1.00
# workers_in thousands_Men                                                1.00
# workers_in_thousands_Women                                              1.00
# Median_weekly_earnings_in_current_dollars_Total                         0.98
# Median_weekly_earnings_in_current_dollars_Men                           0.97
# Median_weekly_earnings_in_current_dollars_Women                         0.99
# Median_weekly_earnings_in_constant_dollars_Total                        0.70
# Median_weekly_earnings_in_constant_dollars_men                          0.64
# Median_weekly_earnings_in_constant_dollars_Women                        0.72
# label                                                                   0.25
#
#                                                   workers_in thousands_Men  \
# Year                                                                  0.99
# Quarter                                                               0.04
# workers_in_thousands_Total                                            1.00
# workers_in thousands_Men                                              1.00
# workers_in_thousands_Women                                            0.99
# Median_weekly_earnings_in_current_dollars_Total                       0.97
# Median_weekly_earnings_in_current_dollars_Men                         0.97
# Median_weekly_earnings_in_current_dollars_Women                       0.98
# Median_weekly_earnings_in_constant_dollars_Total                      0.67
# Median_weekly_earnings_in_constant_dollars_men                        0.61
# Median_weekly_earnings_in_constant_dollars_Women                      0.69
# label                                                                 0.23
#
#                                                   workers_in_thousands_Women  \
# Year                                                                    0.98
# Quarter                                                                 0.06
# workers_in_thousands_Total                                              1.00
# workers_in thousands_Men                                                0.99
# workers_in_thousands_Women                                              1.00
# Median_weekly_earnings_in_current_dollars_Total                         0.98
# Median_weekly_earnings_in_current_dollars_Men                           0.98
# Median_weekly_earnings_in_current_dollars_Women                         0.99
# Median_weekly_earnings_in_constant_dollars_Total                        0.73
# Median_weekly_earnings_in_constant_dollars_men                          0.68
# Median_weekly_earnings_in_constant_dollars_Women                        0.75
# label                                                                   0.27
#
#                                                   Median_weekly_earnings_in_current_dollars_Total  \
# Year                                                                                         0.97
# Quarter                                                                                      0.05
# workers_in_thousands_Total                                                                   0.98
# workers_in thousands_Men                                                                     0.97
# workers_in_thousands_Women                                                                   0.98
# Median_weekly_earnings_in_current_dollars_Total                                              1.00
# Median_weekly_earnings_in_current_dollars_Men                                                0.99
# Median_weekly_earnings_in_current_dollars_Women                                              0.99
# Median_weekly_earnings_in_constant_dollars_Total                                             0.79
# Median_weekly_earnings_in_constant_dollars_men                                               0.73
# Median_weekly_earnings_in_constant_dollars_Women                                             0.77
# label                                                                                        0.28
#
#                                                   Median_weekly_earnings_in_current_dollars_Men  \
# Year                                                                                       0.96
# Quarter                                                                                    0.06
# workers_in_thousands_Total                                                                 0.97
# workers_in thousands_Men                                                                   0.97
# workers_in_thousands_Women                                                                 0.98
# Median_weekly_earnings_in_current_dollars_Total                                            0.99
# Median_weekly_earnings_in_current_dollars_Men                                              1.00
# Median_weekly_earnings_in_current_dollars_Women                                            0.98
# Median_weekly_earnings_in_constant_dollars_Total                                           0.76
# Median_weekly_earnings_in_constant_dollars_men                                             0.75
# Median_weekly_earnings_in_constant_dollars_Women                                           0.73
# label                                                                                      0.31
#
#                                                   Median_weekly_earnings_in_current_dollars_Women  \
# Year                                                                                         0.98
# Quarter                                                                                      0.04
# workers_in_thousands_Total                                                                   0.99
# workers_in thousands_Men                                                                     0.98
# workers_in_thousands_Women                                                                   0.99
# Median_weekly_earnings_in_current_dollars_Total                                              0.99
# Median_weekly_earnings_in_current_dollars_Men                                                0.98
# Median_weekly_earnings_in_current_dollars_Women                                              1.00
# Median_weekly_earnings_in_constant_dollars_Total                                             0.73
# Median_weekly_earnings_in_constant_dollars_men                                               0.65
# Median_weekly_earnings_in_constant_dollars_Women                                             0.77
# label                                                                                        0.22
#
#                                                   Median_weekly_earnings_in_constant_dollars_Total  \
# Year                                                                                          0.65
# Quarter                                                                                       0.04
# workers_in_thousands_Total                                                                    0.70
# workers_in thousands_Men                                                                      0.67
# workers_in_thousands_Women                                                                    0.73
# Median_weekly_earnings_in_current_dollars_Total                                               0.79
# Median_weekly_earnings_in_current_dollars_Men                                                 0.76
# Median_weekly_earnings_in_current_dollars_Women                                               0.73
# Median_weekly_earnings_in_constant_dollars_Total                                              1.00
# Median_weekly_earnings_in_constant_dollars_men                                                0.93
# Median_weekly_earnings_in_constant_dollars_Women                                              0.91
# label                                                                                         0.52
#
#                                                   Median_weekly_earnings_in_constant_dollars_men  \
# Year                                                                                        0.59
# Quarter                                                                                     0.06
# workers_in_thousands_Total                                                                  0.64
# workers_in thousands_Men                                                                    0.61
# workers_in_thousands_Women                                                                  0.68
# Median_weekly_earnings_in_current_dollars_Total                                             0.73
# Median_weekly_earnings_in_current_dollars_Men                                               0.75
# Median_weekly_earnings_in_current_dollars_Women                                             0.65
# Median_weekly_earnings_in_constant_dollars_Total                                            0.93
# Median_weekly_earnings_in_constant_dollars_men                                              1.00
# Median_weekly_earnings_in_constant_dollars_Women                                            0.77
# label                                                                                       0.65
#
#                                                   Median_weekly_earnings_in_constant_dollars_Women  \
# Year                                                                                          0.68
# Quarter                                                                                       0.04
# workers_in_thousands_Total                                                                    0.72
# workers_in thousands_Men                                                                      0.69
# workers_in_thousands_Women                                                                    0.75
# Median_weekly_earnings_in_current_dollars_Total                                               0.77
# Median_weekly_earnings_in_current_dollars_Men                                                 0.73
# Median_weekly_earnings_in_current_dollars_Women                                               0.77
# Median_weekly_earnings_in_constant_dollars_Total                                              0.91
# Median_weekly_earnings_in_constant_dollars_men                                                0.77
# Median_weekly_earnings_in_constant_dollars_Women                                              1.00
# label                                                                                         0.43
#
#                                                   label
# Year                                               0.21
# Quarter                                           -0.01
# workers_in_thousands_Total                         0.25
# workers_in thousands_Men                           0.23
# workers_in_thousands_Women                         0.27
# Median_weekly_earnings_in_current_dollars_Total    0.28
# Median_weekly_earnings_in_current_dollars_Men      0.31
# Median_weekly_earnings_in_current_dollars_Women    0.22
# Median_weekly_earnings_in_constant_dollars_Total   0.52
# Median_weekly_earnings_in_constant_dollars_men     0.65
# Median_weekly_earnings_in_constant_dollars_Women   0.43
# label                                              1.00

# %%
sns.heatmap(cormat);

# %%
from typing import Tuple
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

def show_correlation_graph(df: pd.DataFrame, figsize: Tuple):
    plt.figure(figsize=figsize)
    corrmat = df.corr()
    top_corr_features = corrmat.index
    sns.heatmap(df[top_corr_features].corr(), annot=True, cmap="RdYlGn")
    plt.show()

show_correlation_graph(df,(10,10))

# %% [markdown]
# Hyper Parameters

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
salary_df = pd.read_csv('Salary.csv')
print("Number of Observations in adult dataset:", salary_df.shape)
# Out:
# Number of Observations in adult dataset: (37, 12)

# %%
# plt.figure(figsize =(12,6));
# sns.countplot(x = 'workers_in_thousands_Women', data = salary_df);
# plt.xlabel("workers_in_thousands_Women",fontsize = 12);
# plt.ylabel("label",fontsize = 12);

# %%
X1= df.drop(columns=['Year','Quarter','workers_in_thousands_Total','Median_weekly_earnings_in_constant_dollars_Total',
                     'Median_weekly_earnings_in_current_dollars_Total'],axis=1)
y1 = df[['label']]
print(X1)
type(X1)
type(y1)
# Out:
#     workers_in thousands_Men  workers_in_thousands_Women  \
# 0                      54410                       44145
# 1                      54098                       44045
# 2                      55028                       44577
# 3                      55620                       44792
# 4                      55486                       44472
# 5                      55337                       44333
# 6                      55821                       44526
# 7                      56046                       44449
# 8                      56687                       44650
# 9                      57110                       45051
# 10                     57079                       45447
# 11                     57207                       45380
# 12                     57772                       45977
# 13                     57884                       46044
# 14                     57944                       46044
# 15                     58082                       46318
# 16                     58095                       46669
# 17                     58682                       46951
# 18                     59486                       46855
# 19                     59543                       47183
# 20                     60123                       47313
# 21                     60364                       48122
# 22                     60400                       48144
# 23                     60977                       48292
# 24                     61273                       48776
# 25                     61627                       48799
# 26                     61787                       49142
# 27                     62082                       49483
# 28                     62249                       49214
# 29                     62462                       49516
# 30                     62942                       50176
# 31                     63155                       50468
# 32                     63377                       50996
# 33                     64007                       50671
# 34                     64136                       51345
# 35                     64198                       51747
# 36                     64237                       51923
#
#     Median_weekly_earnings_in_current_dollars_Men  \
# 0                                             823
# 1                                             836
# 2                                             814
# 3                                             821
# 4                                             826
# 5                                             821
# 6                                             830
# 7                                             836
# 8                                             838
# 9                                             841
# 10                                            870
# 11                                            836
# 12                                            868
# 13                                            860
# 14                                            863
# 15                                            855
# 16                                            865
# 17                                            865
# 18                                            860
# 19                                            878
# 20                                            878
# 21                                            886
# 22                                            890
# 23                                            896
# 24                                            904
# 25                                            903
# 26                                            914
# 27                                            917
# 28                                            924
# 29                                            940
# 30                                            939
# 31                                            943
# 32                                            943
# 33                                            955
# 34                                            964
# 35                                            980
# 36                                            991
#
#     Median_weekly_earnings_in_current_dollars_Women  \
# 0                                               666
# 1                                               662
# 2                                               671
# 3                                               670
# 4                                               676
# 5                                               679
# 6                                               687
# 7                                               681
# 8                                               686
# 9                                               693
# 10                                              687
# 11                                              693
# 12                                              690
# 13                                              699
# 14                                              706
# 15                                              705
# 16                                              712
# 17                                              716
# 18                                              715
# 19                                              721
# 20                                              724
# 21                                              724
# 22                                              726
# 23                                              727
# 24                                              730
# 25                                              743
# 26                                              744
# 27                                              750
# 28                                              760
# 29                                              759
# 30                                              780
# 31                                              771
# 32                                              771
# 33                                              776
# 34                                              780
# 35                                              801
# 36                                              796
#
#     Median_weekly_earnings_in_constant_dollars_men  \
# 0                                              379
# 1                                              384
# 2                                              374
# 3                                              377
# 4                                              376
# 5                                              370
# 6                                              370
# 7                                              370
# 8                                              369
# 9                                              368
# 10                                             380
# 11                                             364
# 12                                             375
# 13                                             370
# 14                                             372
# 15                                             367
# 16                                             369
# 17                                             367
# 18                                             363
# 19                                             370
# 20                                             371
# 21                                             377
# 22                                             376
# 23                                             377
# 24                                             380
# 25                                             380
# 26                                             382
# 27                                             381
# 28                                             382
# 29                                             385
# 30                                             385
# 31                                             385
# 32                                             381
# 33                                             383
# 34                                             385
# 35                                             389
# 36                                             392
#
#     Median_weekly_earnings_in_constant_dollars_Women  label
# 0                                                307      1
# 1                                                304      1
# 2                                                309      1
# 3                                                308      1
# 4                                                308      1
# 5                                                306      1
# 6                                                306      1
# 7                                                301      1
# 8                                                302      0
# 9                                                303      0
# 10                                               300      1
# 11                                               302      0
# 12                                               298      1
# 13                                               301      1
# 14                                               304      1
# 15                                               302      0
# 16                                               304      0
# 17                                               304      0
# 18                                               302      0
# 19                                               304      1
# 20                                               306      1
# 21                                               307      1
# 22                                               306      1
# 23                                               306      1
# 24                                               307      1
# 25                                               312      1
# 26                                               311      1
# 27                                               312      1
# 28                                               314      1
# 29                                               311      1
# 30                                               320      1
# 31                                               314      1
# 32                                               312      1
# 33                                               311      1
# 34                                               312      1
# 35                                               318      1
# 36                                               315      1
# pandas.core.frame.DataFrame

# %%
X_train,Xtest,y_train,y_test = train_test_split(X1,y1,test_size=0.3, random_state = 0)


from sklearn import tree

from sklearn.tree import DecisionTreeClassifier
dtree= DecisionTreeClassifier(criterion = 'entropy')
dtree.fit(X_train,y_train)
predictions= dtree.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix

print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
tree.plot_tree(dtree)
plt.rcParams['figure.figsize'] = [16,16]
# Out:
# [[1 2]
#  [1 8]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.50      0.33      0.40         3
#            1       0.80      0.89      0.84         9
#
#     accuracy                           0.75        12
#    macro avg       0.65      0.61      0.62        12
# weighted avg       0.72      0.75      0.73        12

# %%
# data = np.loadtxt('Salary.csv', ndmin=2)

# %%
x = salary_df.Median_weekly_earnings_in_constant_dollars_men
x = [[i] for i in list(x)]
y = salary_df.Median_weekly_earnings_in_constant_dollars_Women
y = [[i] for i in list(y)]

model = SVR(kernel='rbf', C=1.0)
model.fit(x, y)
plt.rcParams["figure.figsize"] = (10,5)
plt.plot(x, y, '.')
plt.plot(x, model.predict(x), '--')
plt.xlabel('Avg. Salary of Men')
plt.ylabel('Avg. Salary of Women')
plt.title("Salary Difference")
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_fit = model.predict(x)
y_fit
# Out:
# array([308.46711673, 311.25658057, 305.45213478, 307.10028913,
#        306.48566359, 304.09944758, 304.09944758, 304.09944758,
#        303.90028914, 303.76767087, 309.16607621, 304.04531054,
#        305.93558777, 304.09944758, 304.66759492, 303.71084515,
#        303.90028914, 303.71084515, 304.31431754, 304.09944758,
#        304.35685412, 307.10028913, 306.48566359, 307.10028913,
#        309.16607621, 309.16607621, 310.41665259, 309.82821383,
#        310.41665259, 311.47687239, 311.47687239, 311.47687239,
#        309.82821383, 310.89997427, 311.47687239, 311.1599953 ,
#        310.18016515])

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y, y_fit)
# Out:
# 12.166894472780811
