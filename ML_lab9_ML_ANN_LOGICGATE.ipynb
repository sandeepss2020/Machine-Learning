# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepss2020/Machine-Learning/blob/main/ML_lab9_ML_ANN_LOGICGATE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# %%
#For OR GATE
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")
target_data = np.array([[0],[1],[1],[1]], "float32")

# %%
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error',
                       optimizer='adam',
                       metrics=['binary_accuracy'])
model.fit(training_data, target_data, epochs=500)
scores = model.evaluate(training_data, target_data)

print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print (model.predict(training_data).round())
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 457ms/step - loss: 0.2506 - binary_accuracy: 0.5000
# Epoch 2/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2499 - binary_accuracy: 0.5000
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2493 - binary_accuracy: 0.5000
# Epoch 4/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2486 - binary_accuracy: 0.5000
# Epoch 5/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2479 - binary_accuracy: 0.5000
# Epoch 6/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2473 - binary_accuracy: 0.5000
# Epoch 7/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2466 - binary_accuracy: 0.5000
# Epoch 8/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2460 - binary_accuracy: 0.5000
# Epoch 9/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2453 - binary_accuracy: 0.5000
# Epoch 10/500
# ...

# %%
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error',
                       optimizer='adam',
                       metrics=['binary_accuracy'])
model.fit(training_data, target_data, epochs=1000)
scores = model.evaluate(training_data, target_data)

print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print (model.predict(training_data).round())
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 819ms/step - loss: 0.4075 - binary_accuracy: 0.2500
# Epoch 2/1000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4051 - binary_accuracy: 0.0000e+00
# Epoch 3/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4028 - binary_accuracy: 0.0000e+00
# Epoch 4/1000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4004 - binary_accuracy: 0.0000e+00
# Epoch 5/1000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3980 - binary_accuracy: 0.0000e+00
# Epoch 6/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3956 - binary_accuracy: 0.0000e+00
# Epoch 7/1000
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3933 - binary_accuracy: 0.0000e+00
# Epoch 8/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3909 - binary_accuracy: 0.0000e+00
# Epoch 9/1000
# ...

# %%
#For AND GATE
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")
target_data = np.array([[0],[0],[0],[1]], "float32")
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='mean_squared_error',
                       optimizer='adam',
                       metrics=['binary_accuracy'])
model.fit(training_data, target_data, epochs=500)
scores = model.evaluate(training_data, target_data)

print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print (model.predict(training_data).round())
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 434ms/step - loss: 0.2525 - binary_accuracy: 0.7500
# Epoch 2/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2518 - binary_accuracy: 0.7500
# Epoch 3/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2511 - binary_accuracy: 0.7500
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2504 - binary_accuracy: 0.7500
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2497 - binary_accuracy: 0.7500
# Epoch 6/500
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2490 - binary_accuracy: 0.7500
# Epoch 7/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2483 - binary_accuracy: 0.7500
# Epoch 8/500
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2476 - binary_accuracy: 0.7500
# Epoch 9/500
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2469 - binary_accuracy: 0.7500
# Epoch 10/500
# ...
